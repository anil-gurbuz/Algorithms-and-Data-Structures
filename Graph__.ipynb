# %%
class Vertex:
    def __init__(self,pair):
        self.id = pair        # Pair object
        self.connectedTo = [] # vertex objects
        self.pred = None
        self.distance = 0
        self.color = 'white'
        self.disc = None
        self.fin = None
        

    def addNeighbor(self,nbr):
        self.connectedTo.append(nbr)

    def __str__(self):
        return str(self.id) + ' connectedTo: ' + str([x.id for x in self.connectedTo])

    def getConnections(self):
        return self.connectedTo

    def getId(self):
        return self.id

    
    
    
    
    
class Graph:
    def __init__(self):
        self.vertList = {0:Vertex(Pair(-1,-1))}   #NUMBERS_from 0 : Vertex_objects
        self.numVertices = 1

    def addVertex(self,pair): 
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(pair)
        self.vertList[max(self.vertList.keys())+1] = newVertex
        return newVertex

    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], cost)

    def getVertices(self):
        return self.vertList.keys()

    def __iter__(self):
        return iter(self.vertList.values())
    
    
    
    def insert(self,pair):
        
        smaller =[]
        bigger = []
        
        
        
        for each_vertex in self:
            
            if each_vertex.id <= pair:
                smaller.append(each_vertex)
                
            if each_vertex.id >cpair:
                bigger.append(each_vertex)

# %%
def bfs(g,start):
    start.distance = 0
    q=Queue()
    q.enqueue(start)
    
    while len(q) > 0 :
        currentVertex = q.pop()
        if currentVertex.color == 'grey':
        currentVertex.color = 'black'
        else:
            continue
        for each_connected in currentVertex.connectedTo :
            if each_connected.color == 'white':
                each_connected.color = 'grey'
                each_connected.pred = currentVertex
                each_connected.distance = currentVertex.distance + 1
                q.enqueue(each_connected)

# %%
class DFSGraph(Graph):
    def __init__(self):
        super().__init__()
        self.time = 0
        
    def dfs(self):
        for aVertex in self:
            aVertex.color = 'white'
        
        for aVertex in self:
            if aVertex.color == 'white':
                self.dfsVisit(aVertex)
            
            
    def dfsVisit(self,startVertex):
        startVertex.color = 'grey'
        self.time +=1
        startVertex.disc = self.time
        
        for next_vertex in startVertex.connectedTo:
            if next_vertex.color == 'white':
                next_vertex.pred = startVertex
                self.dfsVisit(next_vertex)
        
        startVertex.fin = self.time
        startVertex.color = 'black'
