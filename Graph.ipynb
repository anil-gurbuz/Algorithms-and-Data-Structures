# %%
class Vertex:
    def __init__(self,key):
        self.id = key
        self.connectedTo = {}
    
    
    def addNeighbour(self,nbr,weight=0):
        self.connectedTo[nbr]=weight
        
    def __str__(self):
        return str(self.id) + 'Connected to:' + str(x.id for x in self.connectedTo)
    
    def getConnections(self):
        return self.connectedTo.keys()
    
    def getId(self):
        return self.id
    
    def getWeight(self,nbr):
        return self.connectedTo[nbr]
    
    
class Graph:
    def __init__(self):
        self.vertList={}
        self.numVertices = 0
        
    def addVertex(self,key):
        newWertex=Vertex(key)
        self.vertList[key]=newWertex
        self.numVertices+=1
        return newWertex
    
    def getVertex(self,key):
        if key in self.vertList:
            return self.vertList[key]
        else:
            return None
        
        
    def __contains__(self,key):
        return key in self.vertList
    
    
    def addEdge(self,key1,key2,weight=0):
        if key1 not in vertList:
            self.vertList[key1]=Vertex(key1)
        if key2 not in vertList:
            self.vertList[key2]=Vertex(key2)
        self.vertList[key1].addNeighbour(self.vertList[key2], weight)
        
        
    def getVertices(self):
        return self.vertList.keys()
    
    def __iter__(self):
        return self.vertList.values().__iter__()

# %%
from pythonds.graphs import Graph, Vertex
from pythonds.basic import Queue

def bfs(g,start):
    q=queue()
    q.append(start)
    while len(q)>0:
        vertex=q.pop()
        if vertex.colour == 'white':
            vertex.colour='grey'
        if vertex.colour == 'grey':
            continue
        
        for nbr in vertex.connectedTo.keys():
            q.append(nbr)
        
        for each_nbr
        vertex.colour = 'black'
